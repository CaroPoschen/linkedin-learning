# %% [markdown]
# # 02_02: Lists, Tuples, and the Slicing Syntax

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
nephews = ["Huey", "Dewey", "Louie"]

# %%
nephews
# Out:
# ['Huey', 'Dewey', 'Louie']

# %%
len(nephews)
# Out:
# 3

# %%
nephews[0]
# Out:
# 'Huey'

# %%
nephews[2]
# Out:
# 'Louie'

# %%
nephews[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-400cc41c62fc> in <cell line: 1>()
# ----> 1 nephews[3]
#
# IndexError: list index out of range

# %%
nephews[-1], nephews[-2]
# Out:
# ('Louie', 'Dewey')

# %%
for i in range(3):
    nephews[i] = nephews[i] + ' Duck'

# %%
nephews
# Out:
# ['Huey Duck', 'Dewey Duck', 'Louie Duck']

# %%
mix_it_up = [1, [2,3], 'alpha']

# %%
mix_it_up
# Out:
# [1, [2, 3], 'alpha']

# %%
nephews.append('April Duck')

# %%
nephews
# Out:
# ['Huey Duck', 'Dewey Duck', 'Louie Duck', 'April Duck']

# %%
nephews.extend(['May Duck','June Duck'])

# %%
nephews
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'June Duck']

# %%
ducks = nephews + ['Donald Duck','Daisy Duck']

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'June Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
ducks.insert(0, 'Scrooge McDuck')

# %%
ducks
# Out:
# ['Scrooge McDuck',
#  'Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'June Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
del ducks[0]

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'June Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
ducks.remove('Donald Duck')

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'June Duck',
#  'Daisy Duck']

# %%
ducks.sort()

# %%
ducks
# Out:
# ['April Duck',
#  'Daisy Duck',
#  'Dewey Duck',
#  'Huey Duck',
#  'June Duck',
#  'Louie Duck',
#  'May Duck']

# %%
reverse_ducks = sorted(ducks, reverse=True)

# %%
reverse_ducks
# Out:
# ['May Duck',
#  'Louie Duck',
#  'June Duck',
#  'Huey Duck',
#  'Dewey Duck',
#  'Daisy Duck',
#  'April Duck']

# %%
squares = [1,4,9,16,25,36,49]

# %%
squares[0:2]
# Out:
# [1, 4]

# %%
squares[:4]
# Out:
# [1, 4, 9, 16]

# %%
squares[3:]
# Out:
# [16, 25, 36, 49]

# %%
squares[:]
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
squares[0:7:2]
# Out:
# [1, 9, 25, 49]

# %%
squares[-3:-1]
# Out:
# [25, 36]

# %%
squares[2:4] = ['four', 'nine']

# %%
squares
# Out:
# [1, 4, 'four', 'nine', 25, 36, 49]

# %%
del squares[4:6]

# %%
squares
# Out:
# [1, 4, 'four', 'nine', 49]

# %%
len([])
# Out:
# 0

# %%
integers = ('one', 'two', 'three', 'four')

# %%
integers
# Out:
# ('one', 'two', 'three', 'four')

# %%
integers[-1], integers[1:3]
# Out:
# ('four', ('two', 'three'))

# %%
integers[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-13b7737c4ad9> in <cell line: 1>()
# ----> 1 integers[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
(a, b) = (1, 2)

# %%
c, d = 3, 4

# %%
for i, duck in enumerate(ducks):
    print(i, duck)
# Out:
# 0 April Duck
# 1 Daisy Duck
# 2 Dewey Duck
# 3 Huey Duck
# 4 June Duck
# 5 Louie Duck
# 6 May Duck

# %%
def three_args(a, b, c):
    print(a, b, c)

# %%
my_args = (1,2,3)

# %%
three_args(*my_args)
# Out:
# 1 2 3
